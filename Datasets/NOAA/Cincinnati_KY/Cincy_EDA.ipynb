# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Cincy8 = pd.read_csv('Cincinnati2011_2020.csv')
Cincy8.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (33,41,42,43,46,49,51,73,75,89) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        STATION                 DATE REPORT_TYPE  SOURCE  AWND BackupDirection  \
# 0  72421093814  2011-01-02T00:23:00       FM-16       7   NaN              SW
# 1  72421093814  2011-01-02T00:52:00       FM-15       7   NaN              SW
# 2  72421093814  2011-01-02T01:00:00       FM-12       4   NaN              SW
# 3  72421093814  2011-01-02T01:52:00       FM-15       7   NaN              SW
# 4  72421093814  2011-01-02T02:52:00       FM-15       7   NaN              SW
#
#    BackupDistance BackupDistanceUnit      BackupElements  BackupElevation  \
# 0          0.0625                 mi  TEMP, PRECIP, SNOW              NaN
# 1          0.0625                 mi  TEMP, PRECIP, SNOW              NaN
# ...

# %%
Cincy8['HeavyFog'].value_counts()
# Out:
# Series([], Name: HeavyFog, dtype: int64)
